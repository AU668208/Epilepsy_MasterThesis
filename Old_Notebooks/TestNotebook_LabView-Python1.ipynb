# %%
# --- IMPORTS & RELOAD ---
import importlib, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import jeppesen_pipeline as jp

jp = importlib.reload(jp)  # sikrer du bruger nyeste version af modulet
print("Using:", jp.__file__)
# Out:
# Using: c:\Users\kvjkv\.vscode\Epilepsy_MasterThesis\jeppesen_pipeline.py

# %%
# --- PATHS & CONFIG ---
TDMS_PATH  = r"D:\ML algoritme tl anfaldsdetektion vha HRV\ePatch data from Aarhus to Lausanne\Patients ePatch data\Patient 5\recording 1\Patient 5_1.tdms"
INDEX_PATH = r"D:\ML algoritme tl anfaldsdetektion vha HRV\ePatch data from Aarhus to Lausanne\Patients ePatch data\Patient 5\recording 1\Patient 5_1.tdms_index"

# Hvis TDMS ikke indeholder timing-properties, brug fs_override:
FS_OVERRIDE = 512.0

# Slice (kør kun på et tidsudsnit for hastighed)
START_S = 600.0      # fx start 10 min inde = 600 s
DUR_S   = 300.0      # fx 5 minutter

# Pipeline-parametre
WINDOW_BEATS = 50    # lavere for små udsnit (100 kræver ~100 slag)
AUTO_BASELINE_BEATS = 0  # 0 for små slices
OUT_PREFIX = "slice_test"  # præfiks til plots/CSV-filer

# %%
# --- HELPERS ---
def lv_thresholds_for_plot(ecg, fs, params):
    """Returner bp, Thigh, Tlow som i LabVIEW-bygningen, til overlay-plot."""
    bp = jp.bandpass_filter(ecg, fs, 0.5, 32.0, 4)
    L = int(round(params.win_s*fs))
    rect = np.maximum(bp, 0.0)

    # vindue-max
    wmax, edges = [], []
    for st in range(0, len(rect), L):
        en = min(len(rect), st+L)
        wmax.append(np.max(rect[st:en]) if en>st else 0.0)
        edges.append((st,en))
    wmax = np.array(wmax)

    # Thigh pr. vindue (median af seneste 8) * 0.75
    thigh_w = np.zeros_like(wmax)
    for k in range(len(wmax)):
        if k == 0: thigh_w[k] = 0.75*wmax[0]
        else:
            lo = max(0, k-8)
            med = np.median(wmax[lo:k]) if k>0 else wmax[k]
            thigh_w[k] = 0.75*med

    # Kopiér pr. vindue-værdi ud over samples
    thigh = np.zeros(len(bp))
    for k,(st,en) in enumerate(edges):
        thigh[st:en] = thigh_w[k]
    tlow = 0.4*thigh
    return bp, thigh, tlow

def plot_ecg_with_peaks(ecg, fs, peaks, title="ECG + peaks", t0=0.0):
    t = t0 + np.arange(len(ecg))/fs
    plt.figure(figsize=(10,3))
    plt.plot(t, ecg, lw=0.8)
    if len(peaks):
        plt.plot(t0 + peaks/fs, ecg[peaks], "o", ms=4)
    plt.xlabel("Time (s)"); plt.title(title)
    plt.tight_layout(); plt.show()

def plot_overlay(bp, thigh, tlow, fs, peaks=None, start_s=0.0, dur_s=10.0, t0=0.0, title="Thigh/Tlow overlay"):
    j0, j1 = int(start_s*fs), int((start_s+dur_s)*fs)
    tt = t0 + np.arange(len(bp))/fs
    plt.figure(figsize=(10,4))
    plt.plot(tt[j0:j1], bp[j0:j1], label="Filtered ECG")
    plt.plot(tt[j0:j1], thigh[j0:j1], '--', label="Thigh")
    plt.plot(tt[j0:j1], tlow[j0:j1],  '--', label="Tlow")
    if peaks is not None and len(peaks):
        pwin = peaks[(peaks>=j0) & (peaks<j1)]
        plt.plot(tt[pwin], bp[pwin], 'o', label="Peaks")
    plt.legend(); plt.xlabel("Time (s)"); plt.title(title)
    plt.tight_layout(); plt.show()


# Notebook helper: detekter R-peaks med fs-skalering + auto-polaritet,
# selv om jp.LVParams ikke har 'auto_polarity'.
def detect_labview_with_autopol(ecg, fs, auto_polarity="global16s"):
    import numpy as np
    import jeppesen_pipeline as jp

    x = ecg.astype(float).copy()

    # auto-polaritet
    if auto_polarity == "global16s":
        n = int(16*fs)
        seg = x[:min(len(x), n)]
        if seg.size:
            pos95 = np.percentile(seg, 95)
            neg05 = np.percentile(seg, 5)
            if abs(neg05) > pos95:
                x *= -1.0
    elif auto_polarity == "per_window":
        L = int(round(2.0*fs))  # 2 s vinduer som i VI
        for st in range(0, len(x), L):
            en = min(len(x), st+L)
            seg = x[st:en]
            if seg.size and abs(np.min(seg)) > np.max(seg):
                x[st:en] = -seg

    # fs-skalering af sample-baserede konstanter (15 og 35 @256 Hz)
    scale = fs/256.0
    params = jp.LVParams(
        fs=fs,
        fwd_bwd_radius_samp=int(round(15*scale)),
        delta_thresh_samples=int(round(35*scale))
        # resten af LVParams er i sekunder og skal ikke skaleres
    )
    return jp.LabVIEWRpeak(params).detect(x), x  # returnér også evt. polaritets-korrigeret signal

# %%
# --- LOAD TDMS & SLICE ---
x, t_sec, fs, *_ = jp.read_tdms_auto(TDMS_PATH, fs_override=FS_OVERRIDE)

i0, i1 = int(START_S*fs), int((START_S+DUR_S)*fs)
x_win = x[i0:i1]
print(f"Slice: {START_S:.1f}s → {START_S+DUR_S:.1f}s  |  samples: {len(x_win)}  |  fs={fs}")

# --- RUN PIPELINE (LabVIEW-mode) ---
res = jp.run_pipeline_from_ecg(
    ecg=x_win, fs=fs,
    rpeak_mode="labview",          # bruger LVParams(fs=fs, auto_polarity="global16s")
    window_beats=WINDOW_BEATS,
    auto_baseline_beats=AUTO_BASELINE_BEATS,
    plots=True, out=OUT_PREFIX
)
print("Keys:", res.keys())
print("Detected peaks:", len(res["peaks"]))
# Out:
# Slice: 600.0s → 900.0s  |  samples: 153600  |  fs=512.0
# Keys: dict_keys(['peaks', 'rr_sec', 't_rr', 'features', 'detections', 'meta'])
# Detected peaks: 785

# %%
peaks, x_win_pol = detect_labview_with_autopol(x_win, fs, auto_polarity="global16s")

# Plot rå + peaks
plot_ecg_with_peaks(x_win_pol, fs, peaks, title="ECG + peaks (auto-polaritet + fs-skalering)", t0=START_S)

# Overlay Thigh/Tlow (brug params uden auto_polarity)
params = jp.LVParams(fs=fs)
bp, thigh, tlow = lv_thresholds_for_plot(x_win_pol, fs, params)
plot_overlay(bp, thigh, tlow, fs, peaks=peaks,
             start_s=110.0, dur_s=100.0, t0=START_S,
             title="Thigh/Tlow overlay (auto-pol signal)")

# %%
# --- EXPORTS ---
fs_used = fs  # peaks er i "fs" (vi resampler ikke i denne notebook)

peaks = res["peaks"].astype(int)
df_peaks = pd.DataFrame({
    "peak_sample": peaks,
    "peak_time_s": START_S + peaks / float(fs_used)  # absolut tid ift. recording start
})
df_rr = pd.DataFrame({"t_rr_s": START_S + res["t_rr"], "rr_s": res["rr_sec"]})

df_peaks.to_csv(f"{OUT_PREFIX}_peaks.csv", index=False)
df_rr.to_csv(f"{OUT_PREFIX}_rr.csv", index=False)
res["features"].to_csv(f"{OUT_PREFIX}_features.csv", index=False)
res["detections"].to_csv(f"{OUT_PREFIX}_detections.csv", index=False)

print("Saved CSVs:",
      f"{OUT_PREFIX}_peaks.csv",
      f"{OUT_PREFIX}_rr.csv",
      f"{OUT_PREFIX}_features.csv",
      f"{OUT_PREFIX}_detections.csv")

# %%
# Test 29-09-2025

import importlib, jeppesen_pipeline as jp
jp = importlib.reload(jp)

TDMS_PATH  = r"D:\ML algoritme tl anfaldsdetektion vha HRV\ePatch data from Aarhus to Lausanne\Patients ePatch data\Patient 5\recording 1\Patient 5_1.tdms"

# Kør på et 2-minutters udsnit for hastighed
res = jp.run_pipeline_from_tdms_auto(
    tdms_path=TDMS_PATH,
    fs_override=512.0,
    preproc="labview",
    ui_defaults=True,         # bevar øvrige defaults
    delete_start_s=0.0,       # <- vigtig ved korte udsnit
    delete_end_s=0.0,         # <- vigtig ved korte udsnit
    start_s=7*3600+38*60,
    dur_s=120.0,
    rpeak_mode="labview",
    window_beats=50,
    auto_baseline_beats=0,
    plots=True,
    out="slice_labview"
)


# Hurtigt plot: ECG + peaks
import matplotlib.pyplot as plt
ecg = res["ecg_proc"]; fs = res["meta"]["fs_used"]; peaks = res["peaks"]
t0  = res["meta"]["slice_start_s"] or 0.0
tt  = t0 + (np.arange(len(ecg))/fs)
plt.figure(figsize=(10,3))
plt.plot(tt, ecg, lw=0.8)
plt.plot(t0 + peaks/fs, ecg[peaks], "o", ms=4)
plt.xlabel("s"); plt.title("ECG (LabVIEW preproc) + peaks")
plt.tight_layout(); plt.show()

# Eksportér CSV’er til 1:1 sammenligning
import pandas as pd, numpy as np
pd.DataFrame({"peak_sample": peaks,
              "peak_time_s": t0 + peaks/fs}).to_csv("slice_labview_peaks.csv", index=False)
pd.DataFrame({"t_rr_s": t0 + res["t_rr"], "rr_s": res["rr_sec"]}).to_csv("slice_labview_rr.csv", index=False)
res["features"].to_csv("slice_labview_features.csv", index=False)
res["detections"].to_csv("slice_labview_detections.csv", index=False)

# %%
res = jp.run_pipeline_from_tdms_auto(
    tdms_path=TDMS_PATH, fs_override=512.0,
    preproc="labview", ui_defaults=True,
    delete_start_s=0.0, delete_end_s=0.0,   # ved slice
    start_s=7*3600+38*60, dur_s=120.0,
    rpeak_mode="labview",
    window_beats=50, auto_baseline_beats=0,
    plots=True, out="slice_labview"
)
# hvis din LabVIEWRpeak ikke har auto_polarity-parameter:
peaks, x_pol = jp._detect_labview_with_autopol_fallback(
    res["ecg_proc"], res["meta"]["fs_used"], auto_polarity="per_window"
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 11
#       1 res = jp.run_pipeline_from_tdms_auto(
#       2     tdms_path=TDMS_PATH, fs_override=512.0,
#       3     preproc="labview", ui_defaults=True,
#    (...)
#       8     plots=True, out="slice_labview"
#       9 )
#      10 # hvis din LabVIEWRpeak ikke har auto_polarity-parameter:
# ---> 11 peaks, x_pol = jp._detect_labview_with_autopol_fallback(
#      12     res["ecg_proc"], res["meta"]["fs_used"], auto_polarity="per_window"
#      13 )
#
# AttributeError: module 'jeppesen_pipeline' has no attribute '_detect_labview_with_autopol_fallback'

# %%
# Calculate bandpass, Thigh, Tlow using existing helper
params = jp.LVParams(fs=fs)
bp, thigh, tlow = lv_thresholds_for_plot(x_pol, fs, params)

# Plot overlay for the whole signal
plot_overlay(bp, thigh, tlow, fs, peaks=peaks, start_s=0.0, dur_s=len(x_pol)/fs, t0=t0, title="Thigh/Tlow overlay (x_pol)")

# %%
# Zoom in on 2 seconds of the overlay plot
zoom_start_s = 10.0  # choose a start time (in seconds)
zoom_dur_s = 2.0     # duration to zoom in (2 seconds)

plot_overlay(bp, thigh, tlow, fs, peaks=peaks,
             start_s=zoom_start_s, dur_s=zoom_dur_s, t0=t0,
             title=f"Thigh/Tlow overlay ({zoom_start_s}-{zoom_start_s+zoom_dur_s}s)")

# %%
# Different filter
from scipy.signal import butter, filtfilt
def butter_bandpass_1_32(x, fs, order=4):
    nyq = fs/2
    b, a = butter(order, [1.0/nyq, 32.0/nyq], btype="band")
    return filtfilt(b, a, x)

x_bp = butter_bandpass_1_32(res["ecg_proc"], res["meta"]["fs_used"])
# 4-sample moving average
x_bp = np.convolve(x_bp, np.ones(4)/4.0, mode="same")
# kør detektor på x_bp (med per_window polaritet)
peaks, x_bp_pol = jp._detect_labview_with_autopol_fallback(x_bp, res["meta"]["fs_used"], auto_polarity="per_window")

# %%
# Calculate bandpass, Thigh, Tlow using existing helper
params = jp.LVParams(fs=fs)
bp, thigh, tlow = lv_thresholds_for_plot(x_pol, fs, params)

# Plot overlay for the whole signal
plot_overlay(bp, thigh, tlow, fs, peaks=peaks, start_s=0.0, dur_s=len(x_pol)/fs, t0=t0, title="Thigh/Tlow overlay (x_pol)")

# %%
scale = res["meta"]["fs_used"]/256.0
print("lokaliseringsradius ~", int(round(15*scale)), "samples")
print("DELTA-threshold ~", int(round(35*scale)), "samples")
# Out:
# lokaliseringsradius ~ 30 samples
# DELTA-threshold ~ 70 samples

# %%
# Minimal test: tag de Thigh-kryds vi allerede har i overlay-helperen
bp, thigh, tlow = lv_thresholds_for_plot(x_bp_pol, res["meta"]["fs_used"], jp.LVParams(fs=res["meta"]["fs_used"]))
cross = np.where((bp[1:] > thigh[1:]) & (bp[:-1] <= thigh[:-1]))[0] + 1
# Lokaliser max inden for ±radius
radius = int(round(15 * (res["meta"]["fs_used"]/256.0)))
peaks_thigh = []
for i in cross:
    st, en = max(0, i-radius), min(len(bp), i+radius+1)
    peaks_thigh.append(st + np.argmax(bp[st:en]))
peaks_thigh = np.array(sorted(set(peaks_thigh)))

plot_ecg_with_peaks(x_bp_pol, res["meta"]["fs_used"], peaks_thigh, title="Thigh-only test", t0=res["meta"]["slice_start_s"] or 0)

# %%
def rr_from(peaks, fs):
    rr = np.diff(peaks)/fs
    return rr[(rr>=0.3)&(rr<=2.5)]
rr = rr_from(peaks, res["meta"]["fs_used"])
print("n=", len(rr), "median RR=", np.median(rr), "s  (HR≈", 60/np.median(rr), "bpm)")
# Out:
# n= 35 median RR= 0.6171875 s  (HR≈ 97.21518987341773 bpm)

# %%
# 10 sek zoom med bp + Thigh/Tlow + peaks efter per_window + Butterworth
plot_overlay(bp, thigh, tlow, fs, peaks=peaks, start_s=zoom_start_s, dur_s=10.0, t0=t0,
             title="10s zoom: bp + Thigh/Tlow + peaks (per_window + Butterworth)")

# Samme zoom med Thigh-only peaks
plot_ecg_with_peaks(x_bp_pol, fs, peaks_thigh, title="10s zoom: Thigh-only peaks", t0=t0 + zoom_start_s)

# %%
res = jp.run_pipeline_from_tdms_auto(
    tdms_path=TDMS_PATH,
    fs_override=512.0,
    preproc="labview", ui_defaults=True,
    delete_start_s=0.0, delete_end_s=0.0,
    start_s=7*3600+38*60,   # 07:38:00 inde i optagelsen
    dur_s=120.0,            # 2 min udsnit
    rpeak_mode="labview",
    window_beats=50,
    auto_baseline_beats=0,
    plots=True,
    out="slice_labview_thighonly"
)


# tving Thigh-only: lav en detektor med enable_tlow=False
lv = jp.LabVIEWRpeak(jp.LVParams(fs=res["meta"]["fs_used"], enable_tlow=False))
peaks_thighonly = lv.detect(res["ecg_proc"])
# plot
plot_ecg_with_peaks(res["ecg_proc"], res["meta"]["fs_used"], peaks_thighonly,
                    title="Thigh-only peaks", t0=res["meta"]["slice_start_s"] or 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 17
#       1 res = jp.run_pipeline_from_tdms_auto(
#       2     tdms_path=TDMS_PATH,
#       3     fs_override=512.0,
#    (...)
#      12     out="slice_labview_thighonly"
#      13 )
#      16 # tving Thigh-only: lav en detektor med enable_tlow=False
# ---> 17 lv = jp.LabVIEWRpeak(jp.LVParams(fs=res["meta"]["fs_used"], enable_tlow=False))
#      18 peaks_thighonly = lv.detect(res["ecg_proc"])
#      19 # plot
#
# TypeError: LVParams.__init__() got an unexpected keyword argument 'enable_tlow'

# %%
lv_mild = jp.LabVIEWRpeak(jp.LVParams(fs=res["meta"]["fs_used"], enable_tlow=True))
peaks_mild = lv_mild.detect(res["ecg_proc"])
plot_ecg_with_peaks(res["ecg_proc"], res["meta"]["fs_used"], peaks_mild,
                    title="Peaks (Thigh + mild Tlow)", t0=res["meta"]["slice_start_s"] or 0)

# Sammenlign RR
def rr_stats(peaks, fs):
    rr = np.diff(peaks)/fs
    rr = rr[(rr>=0.3)&(rr<=2.5)]
    return len(rr), np.median(rr), 60/np.median(rr)
print("Thigh-only RR:", rr_stats(peaks_thighonly, res["meta"]["fs_used"]))
print("Mild Tlow RR:", rr_stats(peaks_mild, res["meta"]["fs_used"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 lv_mild = jp.LabVIEWRpeak(jp.LVParams(fs=res["meta"]["fs_used"], enable_tlow=True))
#       2 peaks_mild = lv_mild.detect(res["ecg_proc"])
#       3 plot_ecg_with_peaks(res["ecg_proc"], res["meta"]["fs_used"], peaks_mild,
#       4                     title="Peaks (Thigh + mild Tlow)", t0=res["meta"]["slice_start_s"] or 0)
#
# TypeError: LVParams.__init__() got an unexpected keyword argument 'enable_tlow'

# %%
import importlib, inspect, jeppesen_pipeline as jp
jp = importlib.reload(jp)
print(inspect.signature(jp.LVParams))
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\kvjkv\anaconda3\envs\kvj\Lib\site-packages\IPython\core\interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     import importlib, inspect, jeppesen_pipeline as jp
#
#   File c:\Users\kvjkv\.vscode\Epilepsy_MasterThesis\jeppesen_pipeline.py:857
#     fs: float = 256.0
#       ^
# SyntaxError: invalid syntax
